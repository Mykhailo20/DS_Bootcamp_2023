# %%
import numpy as np
import matplotlib.pyplot as plt

import cv2
import imutils
import easyocr

# %% [markdown]
# # 1. Read in Image, Grayscale and Blur

# %%
img = cv2.imread('example_data/image2.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)

# %%
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))
